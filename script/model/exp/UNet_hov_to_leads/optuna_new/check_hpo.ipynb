# %%
import optuna 
import numpy as np 
import os

# %%
# change the names of fn and study_name
# flg = 'rossby'  # change this to 'mjo', 'rossby', 'gravity', or 'raw' as needed
for flg in ['kelvin', 'mjo', 'rossby', 'gravity', 'raw']:
    fn = f'/pscratch/sd/l/linyaoly/MJO_ML_2025/script/model/exp/UNet_hov_to_leads/optuna/UNet_A_lat10_lead35_in_olr_tar_ROMI_{flg}_mem95.db'  
    study = optuna.load_study(study_name=f'UNet_A_lat10_lead35_in_olr_tar_ROMI_{flg}_mem95', storage=f'sqlite:///{fn}')
    print(f'Number of trials {flg}: {len(study.trials)}')
# Out:
# Number of trials kelvin: 56
# Number of trials mjo: 100
# Number of trials rossby: 68
# Number of trials gravity: 91
# Number of trials raw: 99

# %%
# change the names of fn and study_name
# flg = 'rossby'  # change this to 'mjo', 'rossby', 'gravity', or 'raw' as needed
for flg in ['kelvin', 'mjo', 'rossby', 'gravity', 'raw']:
    fn = f'/pscratch/sd/l/linyaoly/MJO_ML_2025/script/model/exp/CNN_2_FCN_3_hov_to_leads/optuna/CNN_MLP_lat10_lead35_in_olr_tar_ROMI_{flg}_mem95.db'  
    study = optuna.load_study(study_name=f'CNN_MLP_lat10_lead35_in_olr_tar_ROMI_{flg}_mem95', storage=f'sqlite:///{fn}')
    print(f'Number of trials {flg}: {len(study.trials)}')
# Out:
# Number of trials kelvin: 100
# Number of trials mjo: 44
# Number of trials rossby: 85
# Number of trials gravity: 100
# Number of trials raw: 51
