# %%
import optuna 
import numpy as np 
import os

# %%
# change the names of fn and study_name
fn = './CNN_MLP_lat10_lead30_in_olr_tar_ROMI_fltano120_mem95.db'  
study = optuna.load_study(study_name='CNN_MLP_lat10_lead30_in_olr_tar_ROMI_fltano120_mem95', storage=f'sqlite:///{fn}')
print(f'Number of trials: {len(study.trials)}')

# If you only want the best trial
print("Best trial hyperparameters:")
print(study.best_trial.params)
# Out:
# Number of trials: 4
# Best trial hyperparameters:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 8
#       6 # If you only want the best trial
#       7 print("Best trial hyperparameters:")
# ----> 8 print(study.best_trial.params)
#
# File /pscratch/sd/l/linyaoly/python/lib/python3.11/site-packages/optuna/study/study.py:162, in Study.best_trial(self)
#     156 if self._is_multi_objective():
#     157     raise RuntimeError(
#     158         "A single best trial cannot be retrieved from a multi-objective study. Consider "
#     159         "using Study.best_trials to retrieve a list containing the best trials."
#     160     )
# --> 162 best_trial = self._storage.get_best_trial(self._study_id)
#     164 # If the trial with the best value is infeasible, select the best trial from all feasible
# ...
